# %% [markdown]
# <a href="https://colab.research.google.com/github/sydoky/Training-maching-selling-analysis/blob/main/FAIML_Project_LearnerNotebook_LowCode_Misha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Fundamentals of AIML: Cardio Good Fitness Data Analysis**
# **Marks: 40**

# %% [markdown]
# ## **Context**
#
# Cardio Good Fitness is a leading manufacturer of high-quality treadmills. The company offers three main products: the TM195, the TM498, and the TM798, which is their flagship product. With the rising demand for fitness in the market and an increasing number of competitors, Cardio Good Fitness wants to gain a better understanding of its existing customer profiles in order to develop more targeted marketing and product development strategies. They believe this will allow them to meet the needs and preferences of their customers, increase customer satisfaction, and drive revenue growth.
#
# <br>
#
# ## **Objective**
#
# In order to gain insights into its customer profiles, Cardio Good Fitness has collected demographic and product usage information for each of its customers. The dataset includes variables such as age, gender, income, and miles run on the treadmill for each of the three products.
#
# Suppose you are hired as a Data Scientist in this company and the Data Science team has shared the data with you. The requirement is to analyze the data and identify patterns in product usage and the key characteristics of customers by conducting exploratory data analysis (EDA) to come up with customer profiles.
#
# The goal is to answer key questions such as:
#
# * What are the key characteristics of customers who purchase each product?
# * How does product usage vary by each group?
#
# <br>
#
# ## **Data Description**
#
# The data is about customers of the treadmill product(s) of a retail store called Cardio Good Fitness. It contains the following variables-
#
#
# * Product - The model no. of the treadmill
# * Age -  Age of the customer in no of years
# * Gender - Gender of the customer
# * Education - Education of the customer in no. of years
# * Marital Status - Marital status of the customer
# * Usage - Avg. number of times the customer wants to use the treadmill every week
# * Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# * Income - Income of the customer
# * Miles- Miles that a customer expects to run

# %% [markdown]
# ### **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned. Read along carefully to complete the project.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. Please replace the blank with the right code snippet. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw an error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * You can the results/observations derived from the analysis here and use them to create your final presentation.

# %% [markdown]
# ### Let us start by importing the required libraries -

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Understanding the structure of the data

# %%
# uncomment and run the following lines for Google Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Read the data
df = pd.read_csv('/content/CardioGoodFitness.csv') ## Fill the blank to read the data
# Returns the first 5 rows
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
# copying data to another variable to avoid any changes to original data
cardio = df.copy()

# %%
# returns the first 5 rows
cardio.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# #### Observations:
# [Write your observation(s) here]

# %% [markdown]
# ### **Question 1:** How many rows and columns are present in the data? [0.5 mark]

# %%
# Check the shape of the dataset
## Fill in the blank
cardio.shape
# Out:
# (180, 9)

# %% [markdown]
# #### Observations:
# [Write your observation(s) here]

# %% [markdown]
# ### **Question 2:** What are the datatypes of the different columns in the dataset? (The info() function can be used) [0.5 mark]

# %%
cardio.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# #### Observations:
# [Write your observation(s) here]

# %% [markdown]
# ### **Question 3:** Write a code to convert the data type of the object type variables to the 'categorical' type to reduce memory usage. [0.5 mark]

# %%
#Write the appropriate function to convert the data type into 'category' for each column
cardio["Product"] = cardio["Product"].astype('category') 
cardio["Gender"] = cardio["Gender"].astype('category')
cardio["MaritalStatus"] = cardio["MaritalStatus"].astype('category')
cardio["Fitness"] = cardio["Fitness"].astype('category')

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    category
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    category
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    category
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    category
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: category(4), int64(5)
# memory usage: 8.4 KB

# %% [markdown]
# ### Observations:
# [Write your observation(s) here]

# %% [markdown]
# ### **Question 4:** Are there any missing values in the data? If yes, treat them using an appropriate method. [0.5 mark]

# %%
# Checking for missing values in the data
  #Write the appropriate function to print the sum of null values for each column
cardio.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# #### Observations:
# [Write your observation(s) here]

# %% [markdown]
# ### **Question 5:** Check the statistical summary of the data. Which product type has had the highest number of sales? [1 marks]

# %%
cardio.describe()
# Out:
#               Age   Education       Usage         Income       Miles
# count  180.000000  180.000000  180.000000     180.000000  180.000000
# mean    28.788889   15.572222    3.455556   53719.577778  103.194444
# std      6.943498    1.617055    1.084797   16506.684226   51.863605
# min     18.000000   12.000000    2.000000   29562.000000   21.000000
# 25%     24.000000   14.000000    3.000000   44058.750000   66.000000
# 50%     26.000000   16.000000    3.000000   50596.500000   94.000000
# 75%     33.000000   16.000000    4.000000   58668.000000  114.750000
# max     50.000000   21.000000    7.000000  104581.000000  360.000000

# %%
cardio["Product"].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
# Get the summary statistics of the numerical data
 ## Write the appropriate function to print the statitical summary of the data

# %% [markdown]
# #### Observations:
# [Write your observation(s) here]

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# ### **Question 6:** Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.) [6 marks]

# %% [markdown]
# Please run the below user-defined function for the univariate analysis.

# %%
cardio
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage Fitness  Income  \
# 0     TM195   18    Male         14        Single      3       4   29562
# 1     TM195   19    Male         15        Single      2       3   31836
# 2     TM195   19  Female         14     Partnered      4       3   30699
# 3     TM195   19    Male         12        Single      3       3   32973
# 4     TM195   20    Male         13     Partnered      4       2   35247
# ..      ...  ...     ...        ...           ...    ...     ...     ...
# 175   TM798   40    Male         21        Single      6       5   83416
# 176   TM798   42    Male         18        Single      5       4   89641
# 177   TM798   45    Male         16        Single      5       5   90886
# 178   TM798   47    Male         18     Partnered      4       5  104581
# 179   TM798   48    Male         18     Partnered      4       5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# ...

# %%
# While doing uni-variate analysis of numerical variables we want to study their central tendency 
# and dispersion.
# Let us write a function that will help us create boxplot and histogram for any input numerical 
# variable.
# This function takes the numerical column as the input and returns the boxplots 
# and histograms for the variable.
# Let us see if this help us write faster and cleaner code.
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ## Observations on Age

# %%
histogram_boxplot(cardio, "Age")

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Education

# %%
histogram_boxplot(cardio, "Education") ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Usage

# %%
histogram_boxplot(cardio,'Usage') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Income

# %%
histogram_boxplot(cardio,'Income') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Miles

# %%
histogram_boxplot(cardio,'Miles') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %%
cardio
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage Fitness  Income  \
# 0     TM195   18    Male         14        Single      3       4   29562
# 1     TM195   19    Male         15        Single      2       3   31836
# 2     TM195   19  Female         14     Partnered      4       3   30699
# 3     TM195   19    Male         12        Single      3       3   32973
# 4     TM195   20    Male         13     Partnered      4       2   35247
# ..      ...  ...     ...        ...           ...    ...     ...     ...
# 175   TM798   40    Male         21        Single      6       5   83416
# 176   TM798   42    Male         18        Single      5       4   89641
# 177   TM798   45    Male         16        Single      5       5   90886
# 178   TM798   47    Male         18     Partnered      4       5  104581
# 179   TM798   48    Male         18     Partnered      4       5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# ...

# %% [markdown]
# Now, we will be creating barplots for the categorical variables in the dataset -

# %% [markdown]
# # **We have to create graphs for categorical variables**

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# ## Observations on Product

# %%
labeled_barplot(cardio, "Product", perc=True)

# %% [markdown]
# ### Observations:

# %% [markdown]
# ### Observations on Gender

# %%
labeled_barplot(cardio,'Gender') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Marital Status

# %%
labeled_barplot(cardio,'MaritalStatus') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Fitness

# %%
cardio.dtypes
# Out:
# Product          category
# Age                 int64
# Gender           category
# Education           int64
# MaritalStatus    category
# Usage               int64
# Fitness          category
# Income              int64
# Miles               int64
# dtype: object

# %%
labeled_barplot(cardio,'Fitness') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Education

# %% [markdown]
# # education is not a part of category

# %%
labeled_barplot(cardio,'Education') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Observations on Usage

# %%
labeled_barplot(cardio,'Usage') ## Complete the code

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ### **Bivariate and Multivariate Analysis**

# %% [markdown]
# ### **Question 7:** Perform bivariate and multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables) [12 marks]

# %% [markdown]
# ### **Bivariate Analysis**

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(cardio.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()
# Out:
# <ipython-input-31-50bce87c1b81>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cardio.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")

# %% [markdown]
# ### Observations:
# [Write your observations here from the above]

# %%
cardio.Education.value_counts()
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %%
cardio
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage Fitness  Income  \
# 0     TM195   18    Male         14        Single      3       4   29562
# 1     TM195   19    Male         15        Single      2       3   31836
# 2     TM195   19  Female         14     Partnered      4       3   30699
# 3     TM195   19    Male         12        Single      3       3   32973
# 4     TM195   20    Male         13     Partnered      4       2   35247
# ..      ...  ...     ...        ...           ...    ...     ...     ...
# 175   TM798   40    Male         21        Single      6       5   83416
# 176   TM798   42    Male         18        Single      5       4   89641
# 177   TM798   45    Male         16        Single      5       5   90886
# 178   TM798   47    Male         18     Partnered      4       5  104581
# 179   TM798   48    Male         18     Partnered      4       5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# ...

# %%
sns.pairplot(data=cardio.drop(["Fitness"],axis=1),hue="Product", diag_kind="kde")
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ### Product vs Age

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Product"], y = cardio["Age"],palette="PuBu")
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Education

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Product"], y = cardio["Education"],palette="PuBu")  ## Complete the code to draw a boxplot between product and education
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Usage

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Product"], y = cardio["Usage"],palette="PuBu"); ## Complete the code to draw a boxplot between product and usage
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Income

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Product"], y = cardio["Income"],palette="PuBu"); ## Complete the code to draw a boxplot between product and income
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Miles

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Product"], y = cardio["Miles"],palette="PuBu");## Complete the code to draw a boxplot between product and miles
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Gender

# %%
plt.figure(figsize=(15,7))
sns.countplot(data = cardio, x = cardio["Product"],hue=cardio["Gender"],palette='winter')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Marital Status

# %%
## Complete the code to draw a countplot between product and marital status
plt.figure(figsize=(15,7))
sns.countplot(data = cardio, x = cardio["Product"],hue=cardio["MaritalStatus"],palette='winter')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Product vs Fitness

# %%
## Complete the code to draw a boxplot between product and fitness
plt.figure(figsize=(15,7))
sns.countplot(data = cardio, x = cardio["Product"],hue=cardio["Fitness"],palette='winter')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ### **Multivariate Analysis**
#
# This will help us to understand and cater needs of customers better based on their gender,marital status, Age etc.

# %% [markdown]
# ## Usage vs Gender vs Marital Status

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Gender"], y = cardio["Usage"],hue=cardio["MaritalStatus"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Gender vs Income

# %%
## Complete the code to draw a boxplot between gender and income
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Gender"], y = cardio["Income"],palette="PuBu");## Complete the code to draw a boxplot between product and miles
plt.show()
#income depends on gender. x = gender , y = income 
#Y depends on X

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Gender vs Income vs Marital Status

# %%
## Complete the code to draw a boxplot between gender vs income vs marital status
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Gender"], y = cardio["Income"],hue=cardio["MaritalStatus"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Gender vs Miles

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Gender"], y = cardio["Miles"],palette="PuBu"); ## Complete the code to draw a boxplot between gender and miles
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %%
cardio
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage Fitness  Income  \
# 0     TM195   18    Male         14        Single      3       4   29562
# 1     TM195   19    Male         15        Single      2       3   31836
# 2     TM195   19  Female         14     Partnered      4       3   30699
# 3     TM195   19    Male         12        Single      3       3   32973
# 4     TM195   20    Male         13     Partnered      4       2   35247
# ..      ...  ...     ...        ...           ...    ...     ...     ...
# 175   TM798   40    Male         21        Single      6       5   83416
# 176   TM798   42    Male         18        Single      5       4   89641
# 177   TM798   45    Male         16        Single      5       5   90886
# 178   TM798   47    Male         18     Partnered      4       5  104581
# 179   TM798   48    Male         18     Partnered      4       5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# ...

# %% [markdown]
# ## Gender vs Miles vs Marital Status

# %%
## Complete the code to draw a boxplot between gender vs miles vs marital status
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Gender"], y = cardio["Miles"],hue=cardio["MaritalStatus"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Gender vs Miles vs Education

# %%
## Complete the code to draw a boxplot between gender vs miles vs educationplt.figure(figsize=(15,7))
plt.figure(figsize=(15,7))
sns.boxplot(data = cardio, x = cardio["Gender"], y = cardio["Miles"],hue=cardio["Education"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Age vs Miles vs Gender

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data = cardio, x = cardio["Age"], y = cardio["Miles"],hue=cardio["Gender"],errorbar=('ci', 0))
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Age vs Miles vs Marital Status

# %%
## Complete the code to draw a lineplot between age vs miles vs marital statusplt.figure(figsize=(15,7))
sns.lineplot(data = cardio, x = cardio["Age"], y = cardio["Miles"],hue=cardio["MaritalStatus"],errorbar=('ci', 0))
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Age vs Income vs Product

# %%
 ## Complete the code to draw a lineplot between age vs income vs product MaritalStatus
sns.lineplot(data = cardio, x = cardio["Age"], y = cardio["Income"],hue=cardio["Product"],errorbar=('ci', 0))
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Income vs Miles vs Education

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data = cardio, x  = cardio["Income"], y = cardio["Miles"],hue=cardio["Education"],palette="Dark2")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ## Income vs Miles vs Product

# %%
 ## Complete the code to draw a scatterplot between age vs miles vs marital status
plt.figure(figsize=(15,7))
sns.scatterplot(data = cardio, x  = cardio["Income"], y = cardio["Miles"],hue=cardio["Product"],palette="Dark2")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# ### Observations:
# [Write your observations here]

# %% [markdown]
# ### **Question 8:** Group the data for each product to build customer profiles and summarize the key characteristics of the customers based on the statistical summary.  [3 marks]

# %% [markdown]
# **Grouping data with respect to products to build customer profiles**

# %%
cardio[cardio["Product"]=="TM195"].describe(include="all")
# Out:
#        Product        Age  Gender  Education MaritalStatus      Usage  \
# count       80  80.000000      80  80.000000            80  80.000000
# unique       1        NaN       2        NaN             2        NaN
# top      TM195        NaN  Female        NaN     Partnered        NaN
# freq        80        NaN      40        NaN            48        NaN
# mean       NaN  28.550000     NaN  15.037500           NaN   3.087500
# std        NaN   7.221452     NaN   1.216383           NaN   0.782624
# min        NaN  18.000000     NaN  12.000000           NaN   2.000000
# 25%        NaN  23.000000     NaN  14.000000           NaN   3.000000
# 50%        NaN  26.000000     NaN  16.000000           NaN   3.000000
# 75%        NaN  33.000000     NaN  16.000000           NaN   4.000000
# max        NaN  50.000000     NaN  18.000000           NaN   5.000000
#
#         Fitness       Income       Miles
# count      80.0     80.00000   80.000000
# unique      5.0          NaN         NaN
# ...

# %%
cardio
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage Fitness  Income  \
# 0     TM195   18    Male         14        Single      3       4   29562
# 1     TM195   19    Male         15        Single      2       3   31836
# 2     TM195   19  Female         14     Partnered      4       3   30699
# 3     TM195   19    Male         12        Single      3       3   32973
# 4     TM195   20    Male         13     Partnered      4       2   35247
# ..      ...  ...     ...        ...           ...    ...     ...     ...
# 175   TM798   40    Male         21        Single      6       5   83416
# 176   TM798   42    Male         18        Single      5       4   89641
# 177   TM798   45    Male         16        Single      5       5   90886
# 178   TM798   47    Male         18     Partnered      4       5  104581
# 179   TM798   48    Male         18     Partnered      4       5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# ...

# %% [markdown]
# ### Observations:
# **TM195 Customer**
#
# [Write your observations here]

# %%
## Fill in the blank with appropriate column names and functions
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Average Age{}".format(g["Age"].mean())) 
#cardio["Product"].___________________
# Out:
# ProductTM195
# Average Age28.55
# ProductTM498
# Average Age28.9
# ProductTM798
# Average Age29.1

# %%
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Average education{}".format(g["Education"].mean()))
# Out:
# ProductTM195
# Average education15.0375
# ProductTM498
# Average education15.116666666666667
# ProductTM798
# Average education17.325

# %%
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Gender{}".format(g["Gender"].value_counts()))
# Out:
# ProductTM195
# GenderFemale    40
# Male      40
# Name: Gender, dtype: int64
# ProductTM498
# GenderMale      31
# Female    29
# Name: Gender, dtype: int64
# ProductTM798
# GenderMale      33
# Female     7
# Name: Gender, dtype: int64

# %%
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Marital status{}".format(g["MaritalStatus"].value_counts()))
# Out:
# ProductTM195
# Marital statusPartnered    48
# Single       32
# Name: MaritalStatus, dtype: int64
# ProductTM498
# Marital statusPartnered    36
# Single       24
# Name: MaritalStatus, dtype: int64
# ProductTM798
# Marital statusPartnered    23
# Single       17
# Name: MaritalStatus, dtype: int64

# %%
cardio.dtypes
# Out:
# Product          category
# Age                 int64
# Gender           category
# Education           int64
# MaritalStatus    category
# Usage               int64
# Fitness          category
# Income              int64
# Miles               int64
# dtype: object

# %%
cardio["Fitness"]=cardio["Fitness"].astype(int)

# %%
#above cell we changed from category. 
#It was giving us an error if I used .mean
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Average fitness{}".format(g["Fitness"].mean()))
# Out:
# ProductTM195
# Average fitness2.9625
# ProductTM498
# Average fitness2.9
# ProductTM798
# Average fitness4.625

# %%
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Average income{}".format(g["Income"].mean()))
# Out:
# ProductTM195
# Average income46418.025
# ProductTM498
# Average income48973.65
# ProductTM798
# Average income75441.575

# %%
group_date = cardio.groupby("Product")
for p,g in group_date:
  print("Product{}".format(p)) 
  print("Average miles{}".format(g["Miles"].mean()))
# Out:
# ProductTM195
# Average miles82.7875
# ProductTM498
# Average miles87.93333333333334
# ProductTM798
# Average miles166.9

# %%
cardio.groupby("Product")

# %% [markdown]
# Below questions we already finished. See above cells.

# %% [markdown]
# ### Observations:
# **TM498 Customer**
#
# [Write your observations here]

# %%
## Fill in the blank with appropriate column names and functions
#cardio[_____________________].___________________

# %% [markdown]
# ### Observations:
# **TM798 Customer**
#
# [Write your observations here]

# %% [markdown]
# ### **Question 9:** Summarize the key characteristics of each product based on the analysis performed. What recommendations would you like to share to help improve the business? [6 marks]

# %% [markdown]
# #### **Conclusion:**
# # **We concluded that TM195 and TM798 are the best choice for selling**
#
# *
# *

# %% [markdown]
# #### **Recommendations:**
# [Write your recommendations for the treadmill company below. You can add as many as you want]
#
# *
# *
